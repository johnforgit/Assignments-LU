# %%
# Q No1
l=[]
for i in range(1,11):
  a=int(input("Enter a number:"))
  if a%2==0:
    l.append(a)
  print(l)

# Q No2
'''List comprehension is a concise and shorthand way of writing lists without the use of for loops.'''
l1=[]
a=int(input("Enter the no of elements:"))
for i in range(1,a+1):
  l1.append(i)
print(l1)
# we can create a list by this way 
# by using a list comprehension we can do it in a single line
l2=[i for i in range(10)]
print(l2)
#we can also use conditional statements in list comprehension
l3=[i for i in range(10) if i%2==0]

# Q No3
n=int(input("Enter a number:"))
num_Dict={i:i*i for i in range(1,n+1)}
print(num_Dict)

# Q No4
pos=0
dist=0
moves={'UP':5,'DOWN':3,'LEFT':3,'RIGHT':2}
while True:
  inp=input("Enter the directions(UP/DOWN/RIGHT/LEFT):")
  dist+=moves[inp]
  in=input("ARE YOU FINISHED(Y/N):")
  if in=='y' or 'Y':
    break
  final_pos=dist-pos
 if type(final_pos)==float:
   final_pos=int(round(final_pos))
  print("The total distance travelled is:",final_pos)
